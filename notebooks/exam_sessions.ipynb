# %%
from agents import SQLiteSession

# %%
session = SQLiteSession("user_123", "../dummy_conversations.db")

# %%
items = await session.get_items()

# %%
items
# Out:
# [{'content': 'List the files in the current directory and tell me how many there are.',
#   'role': 'user'},
#  {'id': '__fake_id__',
#   'summary': [{'text': "**Examining File Listing Options**\n\nI've been going through different approaches to list and count files. My initial thought was `ls | wc -l`, but that includes directories, which isn't ideal. I then considered using `find` to filter by file type but realized that simpler instructions often want everything. I'm now leaning toward using `ls -F` to get a good visual overview, while `ls -Ap | grep -v / | wc -l` is the more precise count. I am going to choose the former.\n\n\n",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
# ...

# %%
items[1].keys()
# Out:
# dict_keys(['id', 'summary', 'type', 'content'])

# %%
items[1]
# Out:
# {'id': '__fake_id__',
#  'summary': [{'text': "**Examining File Listing Options**\n\nI've been going through different approaches to list and count files. My initial thought was `ls | wc -l`, but that includes directories, which isn't ideal. I then considered using `find` to filter by file type but realized that simpler instructions often want everything. I'm now leaning toward using `ls -F` to get a good visual overview, while `ls -Ap | grep -v / | wc -l` is the more precise count. I am going to choose the former.\n\n\n",
#    'type': 'summary_text'}],
#  'type': 'reasoning',
# ...

# %%
# Clear all items from a session
await session.clear_session()
